# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/Colab\ Notebooks/SkinCancer_ISIC/preprocessed_image.zip -d /content/drive/MyDrive/Colab\ Notebooks/SkinCancer_ISIC/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/preprocessed_image/ISIC_2313326.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/preprocessed_image/ISIC_7780173.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/preprocessed_image/ISIC_1293062.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/preprocessed_image/ISIC_5660832.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/preprocessed_image/ISIC_2904922.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/preprocessed_image/ISIC_6146132.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/preprocessed_image/ISIC_1247555.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/preprocessed_image/ISIC_6562273.jpg
# ...

# %%
# !unzip /content/drive/MyDrive/Colab\ Notebooks/SkinCancer_ISIC/isic-2024-challenge.zip -d /content/drive/MyDrive/Colab\ Notebooks/SkinCancer_ISIC/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/train-image/image/ISIC_9874642.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/train-image/image/ISIC_9874656.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/train-image/image/ISIC_9874659.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/train-image/image/ISIC_9874663.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/train-image/image/ISIC_9874742.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/train-image/image/ISIC_9874751.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/train-image/image/ISIC_9874803.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/train-image/image/ISIC_9874805.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/SkinCancer_ISIC/train-image/image/ISIC_9874832.jpg
# ...
